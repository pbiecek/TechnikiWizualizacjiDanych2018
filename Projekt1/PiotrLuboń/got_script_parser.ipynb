# %%
import json

# %%
with open('episodes.json') as f:
    data = json.load(f)

# %%
class Episode:
    
    def __init__(self, s, e):
        self.season = s
        self.episode = e
        self.sex = 0
        self.death = 0
    
    def __str__(self):
        return "S{}E{} {} {}".format(self.season, self.episode, self.sex, self.death)
    
    def to_dict(self):
        return {
            'season': self.season,
            'episode': self.episode,
            'sex': self.sex,
            'death': self.death
        }

# %%
rows = []
for episode in data['episodes']:
    epi = Episode(episode['seasonNum'], episode['episodeNum'])
    for scene in episode['scenes']:
        had_sex = False
        for character in scene['characters']:
            if 'killedBy' in character:
                epi.death = epi.death + 1
            if 'sex' in character:
                had_sex = True
        if had_sex:
            epi.sex = epi.sex + 1
    rows.append(epi)
for row in rows:
    print(str(row))
# Out:
# S1E1 3 4
# S1E2 2 3
# S1E3 1 0
# S1E4 1 1
# S1E5 2 1
# S1E6 0 4
# S1E7 1 1
# S1E8 0 5
# S1E9 2 2
# S1E10 3 2
# S2E1 0 2
# S2E2 3 0
# S2E3 2 2
# S2E4 1 2
# S2E5 0 2
# S2E6 1 8
# S2E7 0 4
# S2E8 1 0
# S2E9 1 2
# S2E10 1 7
# S3E1 0 2
# S3E2 1 0
# S3E3 1 1
# S3E4 0 3
# S3E5 2 4
# S3E6 0 1
# S3E7 2 0
# S3E8 1 3
# S3E9 0 8
# S3E10 0 2
# S4E1 0 1
# S4E2 0 3
# S4E3 2 4
# S4E4 0 0
# S4E5 1 3
# S4E6 4 0
# S4E7 1 4
# S4E8 0 7
# S4E9 0 8
# S4E10 1 3
# S5E1 2 2
# S5E2 0 3
# S5E3 1 2
# S5E4 0 5
# S5E5 1 1
# S5E6 1 1
# S5E7 2 1
# S5E8 0 4
# S5E9 1 2
# S5E10 0 9
# S6E1 0 6
# S6E2 0 5
# S6E3 0 7
# S6E4 1 10
# S6E5 0 6
# S6E6 1 0
# S6E7 0 1
# S6E8 0 7
# S6E9 0 6
# S6E10 1 11
# S7E1 0 0
# S7E2 1 2
# S7E3 1 2
# S7E4 0 0
# S7E5 0 4
# S7E6 0 3
# S7E7 1 2
# S8E1 0 0
# S8E2 0 0
# S8E3 0 0
# S8E4 0 0
# S8E5 0 0
# S8E6 0 0

# %%
import pandas as pd
df1 = pd.DataFrame.from_records([s.to_dict() for s in rows])
df1.to_csv('got_sex_death.csv')

# %%
import networkx as nx

def get_seconds(time_string):
    parts = time_string.split(':')[::-1]
    time = 0
    for i, part in enumerate(parts):
        time = time + (int(part) * (60 ** i))
    return time

print(get_seconds("1:10:20"))
# Out:
# 4220

# %%
graph = nx.Graph()
for episode in data['episodes']:
    season = episode['seasonNum']
    for scene in episode['scenes']:
        scene_length = get_seconds(scene['sceneEnd'])- get_seconds(scene['sceneStart'])
        characters = []
        for character in scene['characters']:
            characters.append(character['name'])
        characters = sorted(characters)
        for i in range(len(characters)):
            for j in range(i+1, len(characters)):
                if graph.has_edge(characters[i], characters[j]):
                    if season in graph[characters[i]][characters[j]]:
                        curr_weight = graph[characters[i]][characters[j]][season]
                        graph[characters[i]][characters[j]][season] = curr_weight + scene_length
                    else:
                        graph[characters[i]][characters[j]][season] = scene_length
                else:
                    graph.add_edge(characters[i],characters[j])
                    graph[characters[i]][characters[j]][season] = scene_length

# %%
class TableRow:

    def __init__(self):
        self.character_1 = None
        self.character_2 = None
        self.season = None
        self.weight = None
        
    def __str__(self):
        return "{} {} {} {}".format(self.character_1, self.character_2, self.season, self.weight)
    
    def to_dict(self):
        return {
            'c_1': self.character_1,
            'c_2': self.character_2,
            'season': self.season,
            'weight': self.weight
        }

# %%
rows = []
for item in list(graph.edges(data=True)):
    for key, value in item[2].items():    
        row = TableRow()
        row.character_1 = item[0]
        row.character_2 = item[1]
        row.season = key
        row.weight = value
        rows.append(row)

# %%
df2 = pd.DataFrame.from_records([s.to_dict() for s in rows])
df2.to_csv('characters.csv')
df2.sort_values(by='weight', ascending=False).head()
# Out:
#                      c_1               c_2  season  weight
# 3463  Daenerys Targaryen  Tyrion Lannister       7    4078
# 4024            Jon Snow    Davos Seaworth       7    4003
# 4047            Jon Snow     Jorah Mormont       7    3743
# 4023            Jon Snow    Davos Seaworth       6    3539
# 4482    Tyrion Lannister         Missandei       7    3457

# %%
class SceneLocation:
    
    def __init__(self, s, e):
        self.season = s
        self.episode = e
        self.location = None
        self.weight = None
        
    def to_dict(self):
        return {
            'season': self.season,
            'episode': self.episode,
            'location': self.location,
            'weight': self.weight
        }

# %%
rows = []
for episode in data['episodes']:
    for scene in episode['scenes']:
        sc = SceneLocation(episode['seasonNum'], episode['episodeNum'])
        sc.weight = get_seconds(scene['sceneEnd'])- get_seconds(scene['sceneStart'])
        sc.location = scene["location"]
        rows.append(sc)
for row in rows:
    print(str(row))
# Out:
# <__main__.SceneLocation object at 0x7f02945ade48>
# <__main__.SceneLocation object at 0x7f02945ade80>
# <__main__.SceneLocation object at 0x7f02945adeb8>
# <__main__.SceneLocation object at 0x7f02945adef0>
# <__main__.SceneLocation object at 0x7f02945adf28>
# <__main__.SceneLocation object at 0x7f02945adf60>
# <__main__.SceneLocation object at 0x7f02945adf98>
# <__main__.SceneLocation object at 0x7f02945adfd0>
# <__main__.SceneLocation object at 0x7f0299a13358>
# <__main__.SceneLocation object at 0x7f02945dedd8>
# <__main__.SceneLocation object at 0x7f02945ded30>
# <__main__.SceneLocation object at 0x7f0299a379e8>
# <__main__.SceneLocation object at 0x7f0299a37630>
# <__main__.SceneLocation object at 0x7f0299a37da0>
# <__main__.SceneLocation object at 0x7f0299a37d68>
# <__main__.SceneLocation object at 0x7f0299a37748>
# <__main__.SceneLocation object at 0x7f0299a37e48>
# <__main__.SceneLocation object at 0x7f0299a37320>
# <__main__.SceneLocation object at 0x7f0299a379b0>
# <__main__.SceneLocation object at 0x7f0299a37940>
# <__main__.SceneLocation object at 0x7f0299a371d0>
# <__main__.SceneLocation object at 0x7f0299a37a20>
# <__main__.SceneLocation object at 0x7f0299a37f98>
# <__main__.SceneLocation object at 0x7f0299a37ef0>
# <__main__.SceneLocation object at 0x7f0299a37278>
# <__main__.SceneLocation object at 0x7f0299a37240>
# <__main__.SceneLocation object at 0x7f0299a37588>
# <__main__.SceneLocation object at 0x7f0299a37be0>
# <__main__.SceneLocation object at 0x7f0299a37c88>
# <__main__.SceneLocation object at 0x7f0299a37390>
# <__main__.SceneLocation object at 0x7f0299a37b70>
# <__main__.SceneLocation object at 0x7f0299a37cf8>
# <__main__.SceneLocation object at 0x7f0299a374a8>
# <__main__.SceneLocation object at 0x7f0299a37eb8>
# <__main__.SceneLocation object at 0x7f0299a37a58>
# <__main__.SceneLocation object at 0x7f0299a37518>
# <__main__.SceneLocation object at 0x7f0299a37550>
# <__main__.SceneLocation object at 0x7f0299a374e0>
# <__main__.SceneLocation object at 0x7f0299a37198>
# <__main__.SceneLocation object at 0x7f0299a377f0>
# <__main__.SceneLocation object at 0x7f0299a37438>
# <__main__.SceneLocation object at 0x7f0299a37358>
# <__main__.SceneLocation object at 0x7f0299a370b8>
# <__main__.SceneLocation object at 0x7f0299a37080>
# <__main__.SceneLocation object at 0x7f0299a375f8>
# <__main__.SceneLocation object at 0x7f0299a376d8>
# <__main__.SceneLocation object at 0x7f0299a25b70>
# <__main__.SceneLocation object at 0x7f0299a25320>
# <__main__.SceneLocation object at 0x7f0299a25c50>
# <__main__.SceneLocation object at 0x7f0299a25a58>
# <__main__.SceneLocation object at 0x7f0299a25390>
# <__main__.SceneLocation object at 0x7f0299a25358>
# <__main__.SceneLocation object at 0x7f0299a25630>
# <__main__.SceneLocation object at 0x7f0299a252e8>
# <__main__.SceneLocation object at 0x7f0299a255c0>
# <__main__.SceneLocation object at 0x7f0299a256a0>
# <__main__.SceneLocation object at 0x7f0299a25d30>
# <__main__.SceneLocation object at 0x7f02cc0b5f98>
# <__main__.SceneLocation object at 0x7f02cc0b5cf8>
# <__main__.SceneLocation object at 0x7f02cc0b5278>
# <__main__.SceneLocation object at 0x7f02cc0b5b38>
# <__main__.SceneLocation object at 0x7f02cc0b5cc0>
# <__main__.SceneLocation object at 0x7f02cc0b5eb8>
# <__main__.SceneLocation object at 0x7f02cc0b5c18>
# <__main__.SceneLocation object at 0x7f02cc0b5f60>
# <__main__.SceneLocation object at 0x7f02cc0b5668>
# <__main__.SceneLocation object at 0x7f02cc0b5e80>
# <__main__.SceneLocation object at 0x7f02cc0b5780>
# <__main__.SceneLocation object at 0x7f02cc0b5748>
# <__main__.SceneLocation object at 0x7f02cc0b5fd0>
# <__main__.SceneLocation object at 0x7f02cc0b57b8>
# <__main__.SceneLocation object at 0x7f02cc0b5a58>
# <__main__.SceneLocation object at 0x7f02cc0b5be0>
# <__main__.SceneLocation object at 0x7f02cc0b58d0>
# <__main__.SceneLocation object at 0x7f02cc0b5898>
# <__main__.SceneLocation object at 0x7f02cc0b5978>
# <__main__.SceneLocation object at 0x7f02cc0b5080>
# <__main__.SceneLocation object at 0x7f02cc0b5908>
# <__main__.SceneLocation object at 0x7f02cc0b5518>
# <__main__.SceneLocation object at 0x7f02cc0b5860>
# <__main__.SceneLocation object at 0x7f02cc0b5c50>
# <__main__.SceneLocation object at 0x7f02cc0b5e10>
# <__main__.SceneLocation object at 0x7f02cc0b5e48>
# <__main__.SceneLocation object at 0x7f02cc0b5048>
# <__main__.SceneLocation object at 0x7f02cc0b5da0>
# <__main__.SceneLocation object at 0x7f02cc0b50f0>
# <__main__.SceneLocation object at 0x7f02cc0b5c88>
# <__main__.SceneLocation object at 0x7f02cc0b5ef0>
# <__main__.SceneLocation object at 0x7f02cc0b5d30>
# <__main__.SceneLocation object at 0x7f02cc0b5438>
# <__main__.SceneLocation object at 0x7f02cc0b54a8>
# <__main__.SceneLocation object at 0x7f02cc0b5f28>
# <__main__.SceneLocation object at 0x7f0293c4aa20>
# <__main__.SceneLocation object at 0x7f0293c4a710>
# <__main__.SceneLocation object at 0x7f0293c4a6a0>
# <__main__.SceneLocation object at 0x7f0293c4a6d8>
# <__main__.SceneLocation object at 0x7f0293c4a358>
# <__main__.SceneLocation object at 0x7f0293c4a780>
# <__main__.SceneLocation object at 0x7f0293c4a4e0>
# <__main__.SceneLocation object at 0x7f0293c4a630>
# <__main__.SceneLocation object at 0x7f0293c4a518>
# <__main__.SceneLocation object at 0x7f0293c4a588>
# <__main__.SceneLocation object at 0x7f0293c4a748>
# <__main__.SceneLocation object at 0x7f0293c4a080>
# <__main__.SceneLocation object at 0x7f0293c4a0b8>
# <__main__.SceneLocation object at 0x7f0293c4a470>
# <__main__.SceneLocation object at 0x7f0293c4a3c8>
# <__main__.SceneLocation object at 0x7f0293c4a160>
# <__main__.SceneLocation object at 0x7f0293c4a7b8>
# <__main__.SceneLocation object at 0x7f0293c4a7f0>
# <__main__.SceneLocation object at 0x7f0293c4a5f8>
# <__main__.SceneLocation object at 0x7f0293c4a668>
# <__main__.SceneLocation object at 0x7f0293c4a898>
# <__main__.SceneLocation object at 0x7f0293c4a828>
# <__main__.SceneLocation object at 0x7f0293c4a8d0>
# <__main__.SceneLocation object at 0x7f0293c4a0f0>
# <__main__.SceneLocation object at 0x7f0293c4a860>
# <__main__.SceneLocation object at 0x7f0293c4a908>
# <__main__.SceneLocation object at 0x7f0293c4a978>
# <__main__.SceneLocation object at 0x7f0293c4a940>
# <__main__.SceneLocation object at 0x7f0293c4a1d0>
# <__main__.SceneLocation object at 0x7f0293c4a240>
# <__main__.SceneLocation object at 0x7f0293c4a278>
# <__main__.SceneLocation object at 0x7f0293c4a2e8>
# <__main__.SceneLocation object at 0x7f0293c4a2b0>
# <__main__.SceneLocation object at 0x7f0293c4a390>
# <__main__.SceneLocation object at 0x7f0293c4a198>
# <__main__.SceneLocation object at 0x7f0293c4a048>
# <__main__.SceneLocation object at 0x7f0293c4a438>
# <__main__.SceneLocation object at 0x7f0293c4a9b0>
# <__main__.SceneLocation object at 0x7f0293c4a128>
# <__main__.SceneLocation object at 0x7f0293c4a208>
# <__main__.SceneLocation object at 0x7f0293c4a4a8>
# <__main__.SceneLocation object at 0x7f0293c4a5c0>
# <__main__.SceneLocation object at 0x7f0293c4a400>
# <__main__.SceneLocation object at 0x7f0293c4a9e8>
# <__main__.SceneLocation object at 0x7f0293c4aa58>
# <__main__.SceneLocation object at 0x7f0293c4a320>
# <__main__.SceneLocation object at 0x7f0293c4aa90>
# <__main__.SceneLocation object at 0x7f0293c4aac8>
# <__main__.SceneLocation object at 0x7f0293c4af60>
# <__main__.SceneLocation object at 0x7f0293bcf048>
# <__main__.SceneLocation object at 0x7f0293bcf080>
# <__main__.SceneLocation object at 0x7f0293bcf0b8>
# <__main__.SceneLocation object at 0x7f0293bcf0f0>
# <__main__.SceneLocation object at 0x7f0293bcf128>
# <__main__.SceneLocation object at 0x7f0293bcf160>
# <__main__.SceneLocation object at 0x7f0293bcf198>
# <__main__.SceneLocation object at 0x7f0293bcf1d0>
# <__main__.SceneLocation object at 0x7f0293bcf208>
# <__main__.SceneLocation object at 0x7f0293bcf240>
# <__main__.SceneLocation object at 0x7f0293bcf278>
# <__main__.SceneLocation object at 0x7f0293bcf2b0>
# <__main__.SceneLocation object at 0x7f0293bcf2e8>
# <__main__.SceneLocation object at 0x7f0293bcf320>
# <__main__.SceneLocation object at 0x7f0293bcf358>
# <__main__.SceneLocation object at 0x7f0293bcf390>
# <__main__.SceneLocation object at 0x7f0293bcf400>
# <__main__.SceneLocation object at 0x7f0293bcf438>
# <__main__.SceneLocation object at 0x7f0293bcf470>
# <__main__.SceneLocation object at 0x7f0293bcf4a8>
# <__main__.SceneLocation object at 0x7f0293bcf4e0>
# <__main__.SceneLocation object at 0x7f0293bcf518>
# <__main__.SceneLocation object at 0x7f0293bcf550>
# <__main__.SceneLocation object at 0x7f0293bcf588>
# <__main__.SceneLocation object at 0x7f0293bcf5c0>
# <__main__.SceneLocation object at 0x7f0293bcf5f8>
# <__main__.SceneLocation object at 0x7f0293bcf630>
# <__main__.SceneLocation object at 0x7f0293bcf668>
# <__main__.SceneLocation object at 0x7f0293bcf6a0>
# <__main__.SceneLocation object at 0x7f0293bcf6d8>
# <__main__.SceneLocation object at 0x7f0293bcf710>
# <__main__.SceneLocation object at 0x7f0293bcf748>
# <__main__.SceneLocation object at 0x7f0293bcf780>
# <__main__.SceneLocation object at 0x7f0293bcf7b8>
# <__main__.SceneLocation object at 0x7f0293bcf7f0>
# <__main__.SceneLocation object at 0x7f0293bcf828>
# <__main__.SceneLocation object at 0x7f0293bcf860>
# <__main__.SceneLocation object at 0x7f0293bcf898>
# <__main__.SceneLocation object at 0x7f0293bcf8d0>
# <__main__.SceneLocation object at 0x7f0293bcf908>
# <__main__.SceneLocation object at 0x7f0293bcf940>
# <__main__.SceneLocation object at 0x7f0293bcf978>
# <__main__.SceneLocation object at 0x7f0293bcf9b0>
# <__main__.SceneLocation object at 0x7f0293bcf9e8>
# <__main__.SceneLocation object at 0x7f0293bcfa20>
# <__main__.SceneLocation object at 0x7f0293bcfa58>
# <__main__.SceneLocation object at 0x7f0293bcfa90>
# <__main__.SceneLocation object at 0x7f0293bcfac8>
# <__main__.SceneLocation object at 0x7f0293bcfb00>
# <__main__.SceneLocation object at 0x7f0293bcfb38>
# <__main__.SceneLocation object at 0x7f0293bcfb70>
# <__main__.SceneLocation object at 0x7f0293bcfba8>
# <__main__.SceneLocation object at 0x7f0293bcfbe0>
# <__main__.SceneLocation object at 0x7f0293bcfc18>
# <__main__.SceneLocation object at 0x7f0293bcfc50>
# <__main__.SceneLocation object at 0x7f0293bcfc88>
# <__main__.SceneLocation object at 0x7f0293bcfcc0>
# <__main__.SceneLocation object at 0x7f0293bcfcf8>
# <__main__.SceneLocation object at 0x7f0293bcfd30>
# <__main__.SceneLocation object at 0x7f0293bcfd68>
# <__main__.SceneLocation object at 0x7f0293bcfda0>
# <__main__.SceneLocation object at 0x7f0293bcfdd8>
# <__main__.SceneLocation object at 0x7f0293bcfe10>
# <__main__.SceneLocation object at 0x7f0293bcfe48>
# <__main__.SceneLocation object at 0x7f0293bcfe80>
# <__main__.SceneLocation object at 0x7f0293bcfeb8>
# <__main__.SceneLocation object at 0x7f0293bcfef0>
# <__main__.SceneLocation object at 0x7f0293bcff28>
# <__main__.SceneLocation object at 0x7f0293bcff60>
# <__main__.SceneLocation object at 0x7f0293bcff98>
# <__main__.SceneLocation object at 0x7f0293bcffd0>
# <__main__.SceneLocation object at 0x7f0293caa7f0>
# <__main__.SceneLocation object at 0x7f0293caa080>
# <__main__.SceneLocation object at 0x7f0293caac88>
# <__main__.SceneLocation object at 0x7f0293caa710>
# <__main__.SceneLocation object at 0x7f0293caa3c8>
# <__main__.SceneLocation object at 0x7f0293caa7b8>
# <__main__.SceneLocation object at 0x7f0293caa780>
# <__main__.SceneLocation object at 0x7f0293caa4a8>
# <__main__.SceneLocation object at 0x7f0293caabe0>
# <__main__.SceneLocation object at 0x7f0293caad68>
# <__main__.SceneLocation object at 0x7f0293caa2b0>
# <__main__.SceneLocation object at 0x7f0293caaac8>
# <__main__.SceneLocation object at 0x7f0293caaf98>
# <__main__.SceneLocation object at 0x7f0293caab70>
# <__main__.SceneLocation object at 0x7f0293caaeb8>
# <__main__.SceneLocation object at 0x7f0293caa400>
# <__main__.SceneLocation object at 0x7f0293caac18>
# <__main__.SceneLocation object at 0x7f0293caa748>
# <__main__.SceneLocation object at 0x7f0293caa438>
# <__main__.SceneLocation object at 0x7f0299a0dba8>
# <__main__.SceneLocation object at 0x7f0299a0d2b0>
# <__main__.SceneLocation object at 0x7f0299a0d9b0>
# <__main__.SceneLocation object at 0x7f0299a0d208>
# <__main__.SceneLocation object at 0x7f0299a0dfd0>
# <__main__.SceneLocation object at 0x7f0299a0d7f0>
# <__main__.SceneLocation object at 0x7f0299a0d710>
# <__main__.SceneLocation object at 0x7f0299a0d5f8>
# <__main__.SceneLocation object at 0x7f0299a0d0b8>
# <__main__.SceneLocation object at 0x7f0293bc1048>
# <__main__.SceneLocation object at 0x7f0293bc1080>
# <__main__.SceneLocation object at 0x7f0293bc10b8>
# <__main__.SceneLocation object at 0x7f0293bc10f0>
# <__main__.SceneLocation object at 0x7f0293bc1128>
# <__main__.SceneLocation object at 0x7f0293bc1160>
# <__main__.SceneLocation object at 0x7f0293bc1198>
# <__main__.SceneLocation object at 0x7f0293bc11d0>
# <__main__.SceneLocation object at 0x7f0293bc1208>
# <__main__.SceneLocation object at 0x7f0293bc1240>
# <__main__.SceneLocation object at 0x7f0293bc1278>
# <__main__.SceneLocation object at 0x7f0293bc12b0>
# <__main__.SceneLocation object at 0x7f0293bc12e8>
# <__main__.SceneLocation object at 0x7f0293bc1320>
# <__main__.SceneLocation object at 0x7f0293bc1358>
# <__main__.SceneLocation object at 0x7f0293bc1390>
# <__main__.SceneLocation object at 0x7f0293bc13c8>
# <__main__.SceneLocation object at 0x7f0293bc1400>
# <__main__.SceneLocation object at 0x7f0293bc1438>
# <__main__.SceneLocation object at 0x7f0293bc1470>
# <__main__.SceneLocation object at 0x7f0293bc14a8>
# <__main__.SceneLocation object at 0x7f0293bc14e0>
# <__main__.SceneLocation object at 0x7f0293bc1518>
# <__main__.SceneLocation object at 0x7f0293bc1550>
# <__main__.SceneLocation object at 0x7f0293bc1588>
# <__main__.SceneLocation object at 0x7f0293bc15c0>
# <__main__.SceneLocation object at 0x7f0293bc15f8>
# <__main__.SceneLocation object at 0x7f0293bc1668>
# <__main__.SceneLocation object at 0x7f0293bc16a0>
# <__main__.SceneLocation object at 0x7f0293bc16d8>
# <__main__.SceneLocation object at 0x7f0293bc1710>
# <__main__.SceneLocation object at 0x7f0293bc1748>
# <__main__.SceneLocation object at 0x7f0293bc1780>
# <__main__.SceneLocation object at 0x7f0293bc17b8>
# <__main__.SceneLocation object at 0x7f0293bc17f0>
# <__main__.SceneLocation object at 0x7f0293bc1828>
# <__main__.SceneLocation object at 0x7f0293bc1860>
# <__main__.SceneLocation object at 0x7f0293bc1898>
# <__main__.SceneLocation object at 0x7f0293bc18d0>
# <__main__.SceneLocation object at 0x7f0293bc1908>
# <__main__.SceneLocation object at 0x7f0293bc1940>
# <__main__.SceneLocation object at 0x7f0293bc1978>
# <__main__.SceneLocation object at 0x7f0293bc19b0>
# <__main__.SceneLocation object at 0x7f0293bc19e8>
# <__main__.SceneLocation object at 0x7f0293bc1a20>
# <__main__.SceneLocation object at 0x7f0293bc1a58>
# <__main__.SceneLocation object at 0x7f0293bc1a90>
# <__main__.SceneLocation object at 0x7f0293bc1ac8>
# <__main__.SceneLocation object at 0x7f0293bc1b00>
# <__main__.SceneLocation object at 0x7f0293bc1b38>
# <__main__.SceneLocation object at 0x7f0293bc1b70>
# <__main__.SceneLocation object at 0x7f0293bc1ba8>
# <__main__.SceneLocation object at 0x7f0293bc1be0>
# <__main__.SceneLocation object at 0x7f0293bc1c18>
# <__main__.SceneLocation object at 0x7f0293bc1c50>
# <__main__.SceneLocation object at 0x7f0293bc1c88>
# <__main__.SceneLocation object at 0x7f0293bc1cc0>
# <__main__.SceneLocation object at 0x7f0293bc1cf8>
# <__main__.SceneLocation object at 0x7f0293bc1d30>
# <__main__.SceneLocation object at 0x7f0293bc1d68>
# <__main__.SceneLocation object at 0x7f0293bc1da0>
# <__main__.SceneLocation object at 0x7f0293bc1dd8>
# <__main__.SceneLocation object at 0x7f0293bc1e10>
# <__main__.SceneLocation object at 0x7f0293bc1e48>
# <__main__.SceneLocation object at 0x7f0293bc1e80>
# <__main__.SceneLocation object at 0x7f0293bc1eb8>
# <__main__.SceneLocation object at 0x7f0293bc1ef0>
# <__main__.SceneLocation object at 0x7f0293bc1f28>
# <__main__.SceneLocation object at 0x7f0293bc1f60>
# <__main__.SceneLocation object at 0x7f0293bc1f98>
# <__main__.SceneLocation object at 0x7f0293bc1fd0>
# <__main__.SceneLocation object at 0x7f0293cf0048>
# <__main__.SceneLocation object at 0x7f0293cf0080>
# <__main__.SceneLocation object at 0x7f0293cf00b8>
# <__main__.SceneLocation object at 0x7f0293cf00f0>
# <__main__.SceneLocation object at 0x7f0293cf0128>
# <__main__.SceneLocation object at 0x7f0293cf0160>
# <__main__.SceneLocation object at 0x7f0293cf0198>
# <__main__.SceneLocation object at 0x7f0293cf01d0>
# <__main__.SceneLocation object at 0x7f0293cf0208>
# <__main__.SceneLocation object at 0x7f0293cf0240>
# <__main__.SceneLocation object at 0x7f0293cf0278>
# <__main__.SceneLocation object at 0x7f0293cf02b0>
# <__main__.SceneLocation object at 0x7f0293cf02e8>
# <__main__.SceneLocation object at 0x7f0293cf0320>
# <__main__.SceneLocation object at 0x7f0293cf0358>
# <__main__.SceneLocation object at 0x7f0293cf0390>
# <__main__.SceneLocation object at 0x7f0293cf03c8>
# <__main__.SceneLocation object at 0x7f0293cf0400>
# <__main__.SceneLocation object at 0x7f0293cf0438>
# <__main__.SceneLocation object at 0x7f0293cf0470>
# <__main__.SceneLocation object at 0x7f0293cf04a8>
# <__main__.SceneLocation object at 0x7f0293cf04e0>
# <__main__.SceneLocation object at 0x7f0293cf0518>
# <__main__.SceneLocation object at 0x7f0293cf0550>
# <__main__.SceneLocation object at 0x7f0293cf0588>
# <__main__.SceneLocation object at 0x7f0293cf05c0>
# <__main__.SceneLocation object at 0x7f0293cf05f8>
# <__main__.SceneLocation object at 0x7f0293cf0630>
# <__main__.SceneLocation object at 0x7f0293cf0668>
# <__main__.SceneLocation object at 0x7f0293cf06a0>
# <__main__.SceneLocation object at 0x7f0293cf06d8>
# <__main__.SceneLocation object at 0x7f0293cf0710>
# <__main__.SceneLocation object at 0x7f0293cf0748>
# <__main__.SceneLocation object at 0x7f0293cf0780>
# <__main__.SceneLocation object at 0x7f0293cf07b8>
# <__main__.SceneLocation object at 0x7f0293cf0860>
# <__main__.SceneLocation object at 0x7f0293cf0898>
# <__main__.SceneLocation object at 0x7f0293cf08d0>
# <__main__.SceneLocation object at 0x7f0293cf0908>
# <__main__.SceneLocation object at 0x7f0293cf0940>
# <__main__.SceneLocation object at 0x7f0293cf0978>
# <__main__.SceneLocation object at 0x7f0293cf09b0>
# <__main__.SceneLocation object at 0x7f0293cf09e8>
# <__main__.SceneLocation object at 0x7f0293cf0a20>
# <__main__.SceneLocation object at 0x7f0293cf0a58>
# <__main__.SceneLocation object at 0x7f0293cf0a90>
# <__main__.SceneLocation object at 0x7f0293cf0ac8>
# <__main__.SceneLocation object at 0x7f0293cf0b00>
# <__main__.SceneLocation object at 0x7f0293cf0b38>
# <__main__.SceneLocation object at 0x7f0293cf0b70>
# <__main__.SceneLocation object at 0x7f0293cf0ba8>
# <__main__.SceneLocation object at 0x7f0293cf0be0>
# <__main__.SceneLocation object at 0x7f0293cf0c18>
# <__main__.SceneLocation object at 0x7f0293cf0c50>
# <__main__.SceneLocation object at 0x7f0293cf0c88>
# <__main__.SceneLocation object at 0x7f0293cf0cc0>
# <__main__.SceneLocation object at 0x7f0293cf0cf8>
# <__main__.SceneLocation object at 0x7f0293cf0d30>
# <__main__.SceneLocation object at 0x7f0293cf0d68>
# <__main__.SceneLocation object at 0x7f0293cf0da0>
# <__main__.SceneLocation object at 0x7f0293cf0dd8>
# <__main__.SceneLocation object at 0x7f0293cf0e10>
# <__main__.SceneLocation object at 0x7f0293cf0e48>
# <__main__.SceneLocation object at 0x7f0293cf0e80>
# <__main__.SceneLocation object at 0x7f0293cf0eb8>
# <__main__.SceneLocation object at 0x7f0293cf0ef0>
# <__main__.SceneLocation object at 0x7f0293cf0f28>
# <__main__.SceneLocation object at 0x7f0293cf0f60>
# <__main__.SceneLocation object at 0x7f0293cf0f98>
# <__main__.SceneLocation object at 0x7f0293cf0fd0>
# <__main__.SceneLocation object at 0x7f0293bc66d8>
# <__main__.SceneLocation object at 0x7f0293bc6048>
# <__main__.SceneLocation object at 0x7f0293bc6080>
# <__main__.SceneLocation object at 0x7f0293bc60b8>
# <__main__.SceneLocation object at 0x7f0293bc60f0>
# <__main__.SceneLocation object at 0x7f0293bc6128>
# <__main__.SceneLocation object at 0x7f0293bc6160>
# <__main__.SceneLocation object at 0x7f0293bc6198>
# <__main__.SceneLocation object at 0x7f0293bc61d0>
# <__main__.SceneLocation object at 0x7f0293bc6208>
# <__main__.SceneLocation object at 0x7f0293bc6240>
# <__main__.SceneLocation object at 0x7f0293bc6278>
# <__main__.SceneLocation object at 0x7f0293bc62b0>
# <__main__.SceneLocation object at 0x7f0293bc62e8>
# <__main__.SceneLocation object at 0x7f0293bc6320>
# <__main__.SceneLocation object at 0x7f0293bc6358>
# <__main__.SceneLocation object at 0x7f0293bc6390>
# <__main__.SceneLocation object at 0x7f0293bc63c8>
# <__main__.SceneLocation object at 0x7f0293bc6400>
# <__main__.SceneLocation object at 0x7f0293bc6438>
# <__main__.SceneLocation object at 0x7f0293bc6470>
# <__main__.SceneLocation object at 0x7f0293bc64a8>
# <__main__.SceneLocation object at 0x7f0293bc64e0>
# <__main__.SceneLocation object at 0x7f0293bc6518>
# <__main__.SceneLocation object at 0x7f0293bc6550>
# <__main__.SceneLocation object at 0x7f0293bc6588>
# <__main__.SceneLocation object at 0x7f0293bc65c0>
# <__main__.SceneLocation object at 0x7f0293bc65f8>
# <__main__.SceneLocation object at 0x7f0293bc6710>
# <__main__.SceneLocation object at 0x7f0293bc6748>
# <__main__.SceneLocation object at 0x7f0293bc6780>
# <__main__.SceneLocation object at 0x7f0293bc67b8>
# <__main__.SceneLocation object at 0x7f0293bc67f0>
# <__main__.SceneLocation object at 0x7f0293bc6828>
# <__main__.SceneLocation object at 0x7f0293bc6860>
# <__main__.SceneLocation object at 0x7f0293bc6898>
# <__main__.SceneLocation object at 0x7f0293bc68d0>
# <__main__.SceneLocation object at 0x7f0293bc6908>
# <__main__.SceneLocation object at 0x7f0293bc6940>
# <__main__.SceneLocation object at 0x7f0293bc6978>
# <__main__.SceneLocation object at 0x7f0293bc69b0>
# <__main__.SceneLocation object at 0x7f0293bc69e8>
# <__main__.SceneLocation object at 0x7f0293bc6a20>
# <__main__.SceneLocation object at 0x7f0293bc6a58>
# <__main__.SceneLocation object at 0x7f0293bc6a90>
# <__main__.SceneLocation object at 0x7f0293bc6ac8>
# <__main__.SceneLocation object at 0x7f0293bc6b00>
# <__main__.SceneLocation object at 0x7f0293bc6b38>
# <__main__.SceneLocation object at 0x7f0293bc6b70>
# <__main__.SceneLocation object at 0x7f0293bc6ba8>
# <__main__.SceneLocation object at 0x7f0293bc6be0>
# <__main__.SceneLocation object at 0x7f0293bc6c18>
# <__main__.SceneLocation object at 0x7f0293bc6c50>
# <__main__.SceneLocation object at 0x7f0293bc6c88>
# <__main__.SceneLocation object at 0x7f0293bc6cc0>
# <__main__.SceneLocation object at 0x7f0293bc6cf8>
# <__main__.SceneLocation object at 0x7f0293bc6d30>
# <__main__.SceneLocation object at 0x7f0293bc6d68>
# <__main__.SceneLocation object at 0x7f0293bc6da0>
# <__main__.SceneLocation object at 0x7f0293bc6dd8>
# <__main__.SceneLocation object at 0x7f0293bc6e10>
# <__main__.SceneLocation object at 0x7f0293bc6e48>
# <__main__.SceneLocation object at 0x7f0293bc6e80>
# <__main__.SceneLocation object at 0x7f0293bc6eb8>
# <__main__.SceneLocation object at 0x7f0293bc6ef0>
# <__main__.SceneLocation object at 0x7f0293bc6f28>
# <__main__.SceneLocation object at 0x7f0293bc6f60>
# <__main__.SceneLocation object at 0x7f0293bc6f98>
# <__main__.SceneLocation object at 0x7f0293bc6fd0>
# <__main__.SceneLocation object at 0x7f0293c49048>
# <__main__.SceneLocation object at 0x7f0293c49080>
# <__main__.SceneLocation object at 0x7f0293c490b8>
# <__main__.SceneLocation object at 0x7f0293c490f0>
# <__main__.SceneLocation object at 0x7f0293c49128>
# <__main__.SceneLocation object at 0x7f0293c49160>
# <__main__.SceneLocation object at 0x7f0293c49198>
# <__main__.SceneLocation object at 0x7f0293c491d0>
# <__main__.SceneLocation object at 0x7f0293c49208>
# <__main__.SceneLocation object at 0x7f0293c49240>
# <__main__.SceneLocation object at 0x7f0293c49278>
# <__main__.SceneLocation object at 0x7f0293c492b0>
# <__main__.SceneLocation object at 0x7f0293c492e8>
# <__main__.SceneLocation object at 0x7f0293c49320>
# <__main__.SceneLocation object at 0x7f0293c49358>
# <__main__.SceneLocation object at 0x7f0293c49390>
# <__main__.SceneLocation object at 0x7f0293c493c8>
# <__main__.SceneLocation object at 0x7f0293c49400>
# <__main__.SceneLocation object at 0x7f0293c49438>
# <__main__.SceneLocation object at 0x7f0293c49470>
# <__main__.SceneLocation object at 0x7f0293c494a8>
# <__main__.SceneLocation object at 0x7f0293c494e0>
# <__main__.SceneLocation object at 0x7f0293c49518>
# <__main__.SceneLocation object at 0x7f0293c49550>
# <__main__.SceneLocation object at 0x7f0293c49588>
# <__main__.SceneLocation object at 0x7f0293c495c0>
# <__main__.SceneLocation object at 0x7f0293c495f8>
# <__main__.SceneLocation object at 0x7f0293c49630>
# <__main__.SceneLocation object at 0x7f0293c49668>
# <__main__.SceneLocation object at 0x7f0293c496a0>
# <__main__.SceneLocation object at 0x7f0293c496d8>
# <__main__.SceneLocation object at 0x7f0293c49710>
# <__main__.SceneLocation object at 0x7f0293c49748>
# <__main__.SceneLocation object at 0x7f0293c49780>
# <__main__.SceneLocation object at 0x7f0293c497b8>
# <__main__.SceneLocation object at 0x7f0293c497f0>
# <__main__.SceneLocation object at 0x7f0293c49828>
# <__main__.SceneLocation object at 0x7f0293c49860>
# <__main__.SceneLocation object at 0x7f0293c49898>
# <__main__.SceneLocation object at 0x7f0293c498d0>
# <__main__.SceneLocation object at 0x7f0293c49908>
# <__main__.SceneLocation object at 0x7f0293c49940>
# <__main__.SceneLocation object at 0x7f0293c49978>
# <__main__.SceneLocation object at 0x7f0293c499b0>
# <__main__.SceneLocation object at 0x7f0293c499e8>
# <__main__.SceneLocation object at 0x7f0293c49a20>
# <__main__.SceneLocation object at 0x7f0293c49a58>
# <__main__.SceneLocation object at 0x7f0293c49a90>
# <__main__.SceneLocation object at 0x7f0293c49ac8>
# <__main__.SceneLocation object at 0x7f0293c49b00>
# <__main__.SceneLocation object at 0x7f0293c49b38>
# <__main__.SceneLocation object at 0x7f0293c49b70>
# <__main__.SceneLocation object at 0x7f0293c49ba8>
# <__main__.SceneLocation object at 0x7f0293c49be0>
# <__main__.SceneLocation object at 0x7f0293c49c18>
# <__main__.SceneLocation object at 0x7f0293c49c50>
# <__main__.SceneLocation object at 0x7f0293c49c88>
# <__main__.SceneLocation object at 0x7f0293c49cc0>
# <__main__.SceneLocation object at 0x7f0293c49cf8>
# <__main__.SceneLocation object at 0x7f0293c49d30>
# <__main__.SceneLocation object at 0x7f0293c49d68>
# <__main__.SceneLocation object at 0x7f0293c49da0>
# <__main__.SceneLocation object at 0x7f0293c49dd8>
# <__main__.SceneLocation object at 0x7f0293c49e10>
# <__main__.SceneLocation object at 0x7f0293c49e48>
# <__main__.SceneLocation object at 0x7f0293c49e80>
# <__main__.SceneLocation object at 0x7f0293c49eb8>
# <__main__.SceneLocation object at 0x7f0293c49ef0>
# <__main__.SceneLocation object at 0x7f0293c49f28>
# <__main__.SceneLocation object at 0x7f0293c49f60>
# <__main__.SceneLocation object at 0x7f0293c49f98>
# <__main__.SceneLocation object at 0x7f0293c49fd0>
# <__main__.SceneLocation object at 0x7f0293cf1048>
# <__main__.SceneLocation object at 0x7f0293cf1080>
# <__main__.SceneLocation object at 0x7f0293cf10b8>
# <__main__.SceneLocation object at 0x7f0293cf10f0>
# <__main__.SceneLocation object at 0x7f0293cf1128>
# <__main__.SceneLocation object at 0x7f0293cf1160>
# <__main__.SceneLocation object at 0x7f0293cf1198>
# <__main__.SceneLocation object at 0x7f0293cf11d0>
# <__main__.SceneLocation object at 0x7f0293cf1208>
# <__main__.SceneLocation object at 0x7f0293cf1240>
# <__main__.SceneLocation object at 0x7f0293cf1278>
# <__main__.SceneLocation object at 0x7f0293cf12b0>
# <__main__.SceneLocation object at 0x7f0293cf12e8>
# <__main__.SceneLocation object at 0x7f0293cf1320>
# <__main__.SceneLocation object at 0x7f0293cf1358>
# <__main__.SceneLocation object at 0x7f0293cf1390>
# <__main__.SceneLocation object at 0x7f0293cf13c8>
# <__main__.SceneLocation object at 0x7f0293cf1400>
# <__main__.SceneLocation object at 0x7f0293cf1438>
# <__main__.SceneLocation object at 0x7f0293cf1470>
# <__main__.SceneLocation object at 0x7f0293cf14a8>
# <__main__.SceneLocation object at 0x7f0293cf14e0>
# <__main__.SceneLocation object at 0x7f0293cf1518>
# <__main__.SceneLocation object at 0x7f0293cf1550>
# <__main__.SceneLocation object at 0x7f0293cf1588>
# <__main__.SceneLocation object at 0x7f0293cf15c0>
# <__main__.SceneLocation object at 0x7f0293cf15f8>
# <__main__.SceneLocation object at 0x7f0293cf1630>
# <__main__.SceneLocation object at 0x7f0293cf1668>
# <__main__.SceneLocation object at 0x7f0293cf16a0>
# <__main__.SceneLocation object at 0x7f0293cf16d8>
# <__main__.SceneLocation object at 0x7f0293cf1710>
# <__main__.SceneLocation object at 0x7f0293cf1748>
# <__main__.SceneLocation object at 0x7f0293cf1780>
# <__main__.SceneLocation object at 0x7f0293cf17b8>
# <__main__.SceneLocation object at 0x7f0293cf17f0>
# <__main__.SceneLocation object at 0x7f0293cf1828>
# <__main__.SceneLocation object at 0x7f0293cf1860>
# <__main__.SceneLocation object at 0x7f0293cf1898>
# <__main__.SceneLocation object at 0x7f0293cf18d0>
# <__main__.SceneLocation object at 0x7f0293cf1908>
# <__main__.SceneLocation object at 0x7f0293cf1940>
# <__main__.SceneLocation object at 0x7f0293cf1978>
# <__main__.SceneLocation object at 0x7f0293cf19b0>
# <__main__.SceneLocation object at 0x7f0293cf19e8>
# <__main__.SceneLocation object at 0x7f0293cf1a20>
# <__main__.SceneLocation object at 0x7f0293cf1a58>
# <__main__.SceneLocation object at 0x7f0293cf1a90>
# <__main__.SceneLocation object at 0x7f0293cf1ac8>
# <__main__.SceneLocation object at 0x7f0293cf1b00>
# <__main__.SceneLocation object at 0x7f0293cf1b38>
# <__main__.SceneLocation object at 0x7f0293cf1b70>
# <__main__.SceneLocation object at 0x7f0293cf1ba8>
# <__main__.SceneLocation object at 0x7f0293cf1be0>
# <__main__.SceneLocation object at 0x7f0293cf1c18>
# <__main__.SceneLocation object at 0x7f0293cf1c50>
# <__main__.SceneLocation object at 0x7f0293cf1c88>
# <__main__.SceneLocation object at 0x7f0293cf1cc0>
# <__main__.SceneLocation object at 0x7f0293cf1cf8>
# <__main__.SceneLocation object at 0x7f0293cf1d30>
# <__main__.SceneLocation object at 0x7f0293cf1d68>
# <__main__.SceneLocation object at 0x7f0293cf1da0>
# <__main__.SceneLocation object at 0x7f0293cf1dd8>
# <__main__.SceneLocation object at 0x7f0293cf1e10>
# <__main__.SceneLocation object at 0x7f0293cf1e48>
# <__main__.SceneLocation object at 0x7f0293cf1e80>
# <__main__.SceneLocation object at 0x7f0293cf1eb8>
# <__main__.SceneLocation object at 0x7f0293cf1ef0>
# <__main__.SceneLocation object at 0x7f0293cf1f28>
# <__main__.SceneLocation object at 0x7f0293cf1f60>
# <__main__.SceneLocation object at 0x7f0293cf1f98>
# <__main__.SceneLocation object at 0x7f0293cf1fd0>
# <__main__.SceneLocation object at 0x7f02945a9048>
# <__main__.SceneLocation object at 0x7f02945a9080>
# <__main__.SceneLocation object at 0x7f02945a90b8>
# <__main__.SceneLocation object at 0x7f02945a90f0>
# <__main__.SceneLocation object at 0x7f02945a9128>
# <__main__.SceneLocation object at 0x7f02945a9160>
# <__main__.SceneLocation object at 0x7f02945a9198>
# <__main__.SceneLocation object at 0x7f02945a91d0>
# <__main__.SceneLocation object at 0x7f02945a9208>
# <__main__.SceneLocation object at 0x7f0293c4acf8>
# <__main__.SceneLocation object at 0x7f02945a9240>
# <__main__.SceneLocation object at 0x7f02945a9278>
# <__main__.SceneLocation object at 0x7f02945a92b0>
# <__main__.SceneLocation object at 0x7f02945a9358>
# <__main__.SceneLocation object at 0x7f02945a9390>
# <__main__.SceneLocation object at 0x7f02945a93c8>
# <__main__.SceneLocation object at 0x7f02945a9400>
# <__main__.SceneLocation object at 0x7f02945a9438>
# <__main__.SceneLocation object at 0x7f02945a9470>
# <__main__.SceneLocation object at 0x7f02945a94a8>
# <__main__.SceneLocation object at 0x7f02945a94e0>
# <__main__.SceneLocation object at 0x7f02945a9518>
# <__main__.SceneLocation object at 0x7f02945a9550>
# <__main__.SceneLocation object at 0x7f02945a9588>
# <__main__.SceneLocation object at 0x7f02945a95c0>
# <__main__.SceneLocation object at 0x7f02945a95f8>
# <__main__.SceneLocation object at 0x7f02945a9630>
# <__main__.SceneLocation object at 0x7f02945a9668>
# <__main__.SceneLocation object at 0x7f02945a96a0>
# <__main__.SceneLocation object at 0x7f02945a96d8>
# <__main__.SceneLocation object at 0x7f02945a9710>
# <__main__.SceneLocation object at 0x7f02945a9748>
# <__main__.SceneLocation object at 0x7f02945a9780>
# <__main__.SceneLocation object at 0x7f02945a97b8>
# <__main__.SceneLocation object at 0x7f02945a97f0>
# <__main__.SceneLocation object at 0x7f02945a9828>
# <__main__.SceneLocation object at 0x7f02945a9860>
# <__main__.SceneLocation object at 0x7f02945a9898>
# <__main__.SceneLocation object at 0x7f02945a98d0>
# <__main__.SceneLocation object at 0x7f02945a9908>
# <__main__.SceneLocation object at 0x7f02945a9940>
# <__main__.SceneLocation object at 0x7f02945a9978>
# <__main__.SceneLocation object at 0x7f02945a99b0>
# <__main__.SceneLocation object at 0x7f02945a99e8>
# <__main__.SceneLocation object at 0x7f02945a9a20>
# <__main__.SceneLocation object at 0x7f02945a9a58>
# <__main__.SceneLocation object at 0x7f02945a9a90>
# <__main__.SceneLocation object at 0x7f02945a9ac8>
# <__main__.SceneLocation object at 0x7f02945a9b00>
# <__main__.SceneLocation object at 0x7f02945a9b38>
# <__main__.SceneLocation object at 0x7f02945a9b70>
# <__main__.SceneLocation object at 0x7f02945a9ba8>
# <__main__.SceneLocation object at 0x7f02945a9be0>
# <__main__.SceneLocation object at 0x7f02945a9c18>
# <__main__.SceneLocation object at 0x7f02945a9c50>
# <__main__.SceneLocation object at 0x7f02945a9c88>
# <__main__.SceneLocation object at 0x7f02945a9cc0>
# <__main__.SceneLocation object at 0x7f02945a9cf8>
# <__main__.SceneLocation object at 0x7f02945a9d30>
# <__main__.SceneLocation object at 0x7f02945a9d68>
# <__main__.SceneLocation object at 0x7f02945a9da0>
# <__main__.SceneLocation object at 0x7f02945a9dd8>
# <__main__.SceneLocation object at 0x7f02945a9e10>
# <__main__.SceneLocation object at 0x7f02945a9e48>
# <__main__.SceneLocation object at 0x7f02945a9e80>
# <__main__.SceneLocation object at 0x7f02945a9eb8>
# <__main__.SceneLocation object at 0x7f02945a9ef0>
# <__main__.SceneLocation object at 0x7f02945a9f28>
# <__main__.SceneLocation object at 0x7f02945a9f60>
# <__main__.SceneLocation object at 0x7f02945a9f98>
# <__main__.SceneLocation object at 0x7f02945a9fd0>
# <__main__.SceneLocation object at 0x7f02945a8048>
# <__main__.SceneLocation object at 0x7f02945a8080>
# <__main__.SceneLocation object at 0x7f02945a80b8>
# <__main__.SceneLocation object at 0x7f02945a80f0>
# <__main__.SceneLocation object at 0x7f02945a8128>
# <__main__.SceneLocation object at 0x7f02945a8160>
# <__main__.SceneLocation object at 0x7f02945a8198>
# <__main__.SceneLocation object at 0x7f02945a81d0>
# <__main__.SceneLocation object at 0x7f02945a8208>
# <__main__.SceneLocation object at 0x7f02945a8240>
# <__main__.SceneLocation object at 0x7f02945a8278>
# <__main__.SceneLocation object at 0x7f02945a82b0>
# <__main__.SceneLocation object at 0x7f02945a82e8>
# <__main__.SceneLocation object at 0x7f02945a8320>
# <__main__.SceneLocation object at 0x7f02945a8358>
# <__main__.SceneLocation object at 0x7f02945a8390>
# <__main__.SceneLocation object at 0x7f02945a83c8>
# <__main__.SceneLocation object at 0x7f02945a8400>
# <__main__.SceneLocation object at 0x7f02945a8438>
# <__main__.SceneLocation object at 0x7f02945a8470>
# <__main__.SceneLocation object at 0x7f02945a84a8>
# <__main__.SceneLocation object at 0x7f02945a84e0>
# <__main__.SceneLocation object at 0x7f02945a8518>
# <__main__.SceneLocation object at 0x7f02945a8550>
# <__main__.SceneLocation object at 0x7f02945a8588>
# <__main__.SceneLocation object at 0x7f02945a85c0>
# <__main__.SceneLocation object at 0x7f02945a85f8>
# <__main__.SceneLocation object at 0x7f02945a8630>
# <__main__.SceneLocation object at 0x7f02945a8668>
# <__main__.SceneLocation object at 0x7f02945a86a0>
# <__main__.SceneLocation object at 0x7f02945a86d8>
# <__main__.SceneLocation object at 0x7f02945a8710>
# <__main__.SceneLocation object at 0x7f02945a8780>
# <__main__.SceneLocation object at 0x7f02945a8748>
# <__main__.SceneLocation object at 0x7f02945a87b8>
# <__main__.SceneLocation object at 0x7f02945a87f0>
# <__main__.SceneLocation object at 0x7f02945a8828>
# <__main__.SceneLocation object at 0x7f02945a8860>
# <__main__.SceneLocation object at 0x7f02945a8898>
# <__main__.SceneLocation object at 0x7f02945a88d0>
# <__main__.SceneLocation object at 0x7f02945a8908>
# <__main__.SceneLocation object at 0x7f02945a8940>
# <__main__.SceneLocation object at 0x7f02945a8978>
# <__main__.SceneLocation object at 0x7f02945a89b0>
# <__main__.SceneLocation object at 0x7f02945a89e8>
# <__main__.SceneLocation object at 0x7f02945a8a20>
# <__main__.SceneLocation object at 0x7f02945a8a58>
# <__main__.SceneLocation object at 0x7f02945a8a90>
# <__main__.SceneLocation object at 0x7f02945a8ac8>
# <__main__.SceneLocation object at 0x7f02945a8b00>
# <__main__.SceneLocation object at 0x7f02945a8b38>
# <__main__.SceneLocation object at 0x7f02945a8b70>
# <__main__.SceneLocation object at 0x7f02945a8ba8>
# <__main__.SceneLocation object at 0x7f02945a8be0>
# <__main__.SceneLocation object at 0x7f02945a8c18>
# <__main__.SceneLocation object at 0x7f02945a8c50>
# <__main__.SceneLocation object at 0x7f02945a8c88>
# <__main__.SceneLocation object at 0x7f02945a8cc0>
# <__main__.SceneLocation object at 0x7f02945a8cf8>
# <__main__.SceneLocation object at 0x7f02945a8d30>
# <__main__.SceneLocation object at 0x7f02945a8d68>
# <__main__.SceneLocation object at 0x7f02945a8da0>
# <__main__.SceneLocation object at 0x7f02945a8dd8>
# <__main__.SceneLocation object at 0x7f02945a8e10>
# <__main__.SceneLocation object at 0x7f02945a8e48>
# <__main__.SceneLocation object at 0x7f02945a8e80>
# <__main__.SceneLocation object at 0x7f02945a8eb8>
# <__main__.SceneLocation object at 0x7f02945a8ef0>
# <__main__.SceneLocation object at 0x7f02945a8f28>
# <__main__.SceneLocation object at 0x7f02945a8f60>
# <__main__.SceneLocation object at 0x7f02945a8f98>
# <__main__.SceneLocation object at 0x7f02945a8fd0>
# <__main__.SceneLocation object at 0x7f02945a2048>
# <__main__.SceneLocation object at 0x7f02945a2080>
# <__main__.SceneLocation object at 0x7f02945a20b8>
# <__main__.SceneLocation object at 0x7f02945a20f0>
# <__main__.SceneLocation object at 0x7f02945a2128>
# <__main__.SceneLocation object at 0x7f02945a2160>
# <__main__.SceneLocation object at 0x7f02945a2198>
# <__main__.SceneLocation object at 0x7f02945a21d0>
# <__main__.SceneLocation object at 0x7f02945a2208>
# <__main__.SceneLocation object at 0x7f02945a2240>
# <__main__.SceneLocation object at 0x7f02945a2278>
# <__main__.SceneLocation object at 0x7f02945a22b0>
# <__main__.SceneLocation object at 0x7f02945a22e8>
# <__main__.SceneLocation object at 0x7f02945a2320>
# <__main__.SceneLocation object at 0x7f02945a2358>
# <__main__.SceneLocation object at 0x7f02945a2390>
# <__main__.SceneLocation object at 0x7f02945a23c8>
# <__main__.SceneLocation object at 0x7f02945a2400>
# <__main__.SceneLocation object at 0x7f02945a2438>
# <__main__.SceneLocation object at 0x7f02945a2470>
# <__main__.SceneLocation object at 0x7f02945a24a8>
# <__main__.SceneLocation object at 0x7f02945a24e0>
# <__main__.SceneLocation object at 0x7f02945a2518>
# <__main__.SceneLocation object at 0x7f02945a2550>
# <__main__.SceneLocation object at 0x7f02945a2588>
# <__main__.SceneLocation object at 0x7f02945a25c0>
# <__main__.SceneLocation object at 0x7f02945a25f8>
# <__main__.SceneLocation object at 0x7f02945a2630>
# <__main__.SceneLocation object at 0x7f02945a2668>
# <__main__.SceneLocation object at 0x7f02945a26a0>
# <__main__.SceneLocation object at 0x7f02945a26d8>
# <__main__.SceneLocation object at 0x7f02945a2710>
# <__main__.SceneLocation object at 0x7f02945a2748>
# <__main__.SceneLocation object at 0x7f02945a2780>
# <__main__.SceneLocation object at 0x7f02945a27b8>
# <__main__.SceneLocation object at 0x7f02945a27f0>
# <__main__.SceneLocation object at 0x7f02945a2828>
# <__main__.SceneLocation object at 0x7f02945a2860>
# <__main__.SceneLocation object at 0x7f02945a2898>
# <__main__.SceneLocation object at 0x7f02945a28d0>
# <__main__.SceneLocation object at 0x7f02945a2908>
# <__main__.SceneLocation object at 0x7f02945a2940>
# <__main__.SceneLocation object at 0x7f02945a2978>
# <__main__.SceneLocation object at 0x7f02945a29b0>
# <__main__.SceneLocation object at 0x7f02945a29e8>
# <__main__.SceneLocation object at 0x7f02945a2a20>
# <__main__.SceneLocation object at 0x7f02945a2a58>
# <__main__.SceneLocation object at 0x7f02945a2a90>
# <__main__.SceneLocation object at 0x7f02945a2ac8>
# <__main__.SceneLocation object at 0x7f02945a2b00>
# <__main__.SceneLocation object at 0x7f02945a2b38>
# <__main__.SceneLocation object at 0x7f02945a2b70>
# <__main__.SceneLocation object at 0x7f02945a2ba8>
# <__main__.SceneLocation object at 0x7f02945a2be0>
# <__main__.SceneLocation object at 0x7f02945a2c18>
# <__main__.SceneLocation object at 0x7f02945a2c50>
# <__main__.SceneLocation object at 0x7f02945a2c88>
# <__main__.SceneLocation object at 0x7f02945a2cc0>
# <__main__.SceneLocation object at 0x7f02945a2cf8>
# <__main__.SceneLocation object at 0x7f02945a2d30>
# <__main__.SceneLocation object at 0x7f02945a2d68>
# <__main__.SceneLocation object at 0x7f02945a2da0>
# <__main__.SceneLocation object at 0x7f02945a2dd8>
# <__main__.SceneLocation object at 0x7f02945a2e10>
# <__main__.SceneLocation object at 0x7f02945a2e48>
# <__main__.SceneLocation object at 0x7f02945a2e80>
# <__main__.SceneLocation object at 0x7f02945a2eb8>
# <__main__.SceneLocation object at 0x7f02945a2ef0>
# <__main__.SceneLocation object at 0x7f02945a2f28>
# <__main__.SceneLocation object at 0x7f02945a2f60>
# <__main__.SceneLocation object at 0x7f02945a2f98>
# <__main__.SceneLocation object at 0x7f02945a2fd0>
# <__main__.SceneLocation object at 0x7f02945a1048>
# <__main__.SceneLocation object at 0x7f02945a1080>
# <__main__.SceneLocation object at 0x7f02945a10b8>
# <__main__.SceneLocation object at 0x7f02945a10f0>
# <__main__.SceneLocation object at 0x7f02945a1128>
# <__main__.SceneLocation object at 0x7f02945a1160>
# <__main__.SceneLocation object at 0x7f02945a1198>
# <__main__.SceneLocation object at 0x7f02945a11d0>
# <__main__.SceneLocation object at 0x7f02945a1208>
# <__main__.SceneLocation object at 0x7f02945a1240>
# <__main__.SceneLocation object at 0x7f02945a1278>
# <__main__.SceneLocation object at 0x7f02945a12b0>
# <__main__.SceneLocation object at 0x7f02945a12e8>
# <__main__.SceneLocation object at 0x7f02945a1320>
# <__main__.SceneLocation object at 0x7f02945a1358>
# <__main__.SceneLocation object at 0x7f02945a1390>
# <__main__.SceneLocation object at 0x7f02945a13c8>
# <__main__.SceneLocation object at 0x7f02945a1400>
# <__main__.SceneLocation object at 0x7f02945a1438>
# <__main__.SceneLocation object at 0x7f02945a1470>
# <__main__.SceneLocation object at 0x7f02945a14a8>
# <__main__.SceneLocation object at 0x7f02945a14e0>
# <__main__.SceneLocation object at 0x7f02945a1518>
# <__main__.SceneLocation object at 0x7f02945a1550>
# <__main__.SceneLocation object at 0x7f02945a1588>
# <__main__.SceneLocation object at 0x7f02945a15c0>
# <__main__.SceneLocation object at 0x7f02945a15f8>
# <__main__.SceneLocation object at 0x7f02945a1630>
# <__main__.SceneLocation object at 0x7f02945a1668>
# <__main__.SceneLocation object at 0x7f02945a16a0>
# <__main__.SceneLocation object at 0x7f02945a16d8>
# <__main__.SceneLocation object at 0x7f02945a1710>
# <__main__.SceneLocation object at 0x7f02945a1748>
# <__main__.SceneLocation object at 0x7f02945a1780>
# <__main__.SceneLocation object at 0x7f02945a17b8>
# <__main__.SceneLocation object at 0x7f02945a17f0>
# <__main__.SceneLocation object at 0x7f02945a1828>
# <__main__.SceneLocation object at 0x7f02945a1860>
# <__main__.SceneLocation object at 0x7f02945a1898>
# <__main__.SceneLocation object at 0x7f02945a18d0>
# <__main__.SceneLocation object at 0x7f02945a1908>
# <__main__.SceneLocation object at 0x7f02945a1940>
# <__main__.SceneLocation object at 0x7f02945a1978>
# <__main__.SceneLocation object at 0x7f02945a19b0>
# <__main__.SceneLocation object at 0x7f02945a19e8>
# <__main__.SceneLocation object at 0x7f02945a1a20>
# <__main__.SceneLocation object at 0x7f02945a1a58>
# <__main__.SceneLocation object at 0x7f02945a1a90>
# <__main__.SceneLocation object at 0x7f02945a1ac8>
# <__main__.SceneLocation object at 0x7f02945a1b00>
# <__main__.SceneLocation object at 0x7f02945a1b38>
# <__main__.SceneLocation object at 0x7f02945a1b70>
# <__main__.SceneLocation object at 0x7f02945a1ba8>
# <__main__.SceneLocation object at 0x7f02945a1be0>
# <__main__.SceneLocation object at 0x7f02945a1c18>
# <__main__.SceneLocation object at 0x7f02945a1c50>
# <__main__.SceneLocation object at 0x7f02945a1c88>
# <__main__.SceneLocation object at 0x7f02945a1cc0>
# <__main__.SceneLocation object at 0x7f02945a1cf8>
# <__main__.SceneLocation object at 0x7f02945a1d30>
# <__main__.SceneLocation object at 0x7f02945a1d68>
# <__main__.SceneLocation object at 0x7f02945a1da0>
# <__main__.SceneLocation object at 0x7f02945a1dd8>
# <__main__.SceneLocation object at 0x7f02945a1e10>
# <__main__.SceneLocation object at 0x7f02945a1e48>
# <__main__.SceneLocation object at 0x7f02945a1e80>
# <__main__.SceneLocation object at 0x7f02945a1eb8>
# <__main__.SceneLocation object at 0x7f02945a1ef0>
# <__main__.SceneLocation object at 0x7f02945a1f28>
# <__main__.SceneLocation object at 0x7f02945a1f60>
# <__main__.SceneLocation object at 0x7f02945a1f98>
# <__main__.SceneLocation object at 0x7f02945a1fd0>
# <__main__.SceneLocation object at 0x7f02945ac048>
# <__main__.SceneLocation object at 0x7f02945ac080>
# <__main__.SceneLocation object at 0x7f02945ac0b8>
# <__main__.SceneLocation object at 0x7f02945ac0f0>
# <__main__.SceneLocation object at 0x7f02945ac128>
# <__main__.SceneLocation object at 0x7f02945ac160>
# <__main__.SceneLocation object at 0x7f02945ac198>
# <__main__.SceneLocation object at 0x7f02945ac1d0>
# <__main__.SceneLocation object at 0x7f02945ac208>
# <__main__.SceneLocation object at 0x7f02945ac240>
# <__main__.SceneLocation object at 0x7f02945ac278>
# <__main__.SceneLocation object at 0x7f02945ac2b0>
# <__main__.SceneLocation object at 0x7f02945ac2e8>
# <__main__.SceneLocation object at 0x7f02945ac320>
# <__main__.SceneLocation object at 0x7f02945ac358>
# <__main__.SceneLocation object at 0x7f02945ac390>
# <__main__.SceneLocation object at 0x7f02945ac3c8>
# <__main__.SceneLocation object at 0x7f02945ac400>
# <__main__.SceneLocation object at 0x7f02945ac438>
# <__main__.SceneLocation object at 0x7f02945ac470>
# <__main__.SceneLocation object at 0x7f02945ac4a8>
# <__main__.SceneLocation object at 0x7f02945ac4e0>
# <__main__.SceneLocation object at 0x7f02945ac518>
# <__main__.SceneLocation object at 0x7f02945ac550>
# <__main__.SceneLocation object at 0x7f02945ac588>
# <__main__.SceneLocation object at 0x7f02945ac5c0>
# <__main__.SceneLocation object at 0x7f02945ac5f8>
# <__main__.SceneLocation object at 0x7f02945ac630>
# <__main__.SceneLocation object at 0x7f02945ac668>
# <__main__.SceneLocation object at 0x7f02945ac6a0>
# <__main__.SceneLocation object at 0x7f02945ac6d8>
# <__main__.SceneLocation object at 0x7f02945ac710>
# <__main__.SceneLocation object at 0x7f02945ac748>
# <__main__.SceneLocation object at 0x7f02945ac780>
# <__main__.SceneLocation object at 0x7f02945ac7b8>
# <__main__.SceneLocation object at 0x7f02945ac7f0>
# <__main__.SceneLocation object at 0x7f02945ac828>
# <__main__.SceneLocation object at 0x7f02945ac860>
# <__main__.SceneLocation object at 0x7f02945ac898>
# <__main__.SceneLocation object at 0x7f02945ac8d0>
# <__main__.SceneLocation object at 0x7f02945ac908>
# <__main__.SceneLocation object at 0x7f02945ac940>
# <__main__.SceneLocation object at 0x7f02945ac978>
# <__main__.SceneLocation object at 0x7f02945ac9b0>
# <__main__.SceneLocation object at 0x7f02945ac9e8>
# <__main__.SceneLocation object at 0x7f02945aca20>
# <__main__.SceneLocation object at 0x7f02945aca58>
# <__main__.SceneLocation object at 0x7f02945aca90>
# <__main__.SceneLocation object at 0x7f02945acac8>
# <__main__.SceneLocation object at 0x7f02945acb00>
# <__main__.SceneLocation object at 0x7f02945acb38>
# <__main__.SceneLocation object at 0x7f02945acb70>
# <__main__.SceneLocation object at 0x7f02945acba8>
# <__main__.SceneLocation object at 0x7f02945acbe0>
# <__main__.SceneLocation object at 0x7f02945acc18>
# <__main__.SceneLocation object at 0x7f02945acc50>
# <__main__.SceneLocation object at 0x7f02945acc88>
# <__main__.SceneLocation object at 0x7f02945accc0>
# <__main__.SceneLocation object at 0x7f02945accf8>
# <__main__.SceneLocation object at 0x7f02945acd30>
# <__main__.SceneLocation object at 0x7f02945acd68>
# <__main__.SceneLocation object at 0x7f02945acda0>
# <__main__.SceneLocation object at 0x7f02945acdd8>
# <__main__.SceneLocation object at 0x7f02945ace10>
# <__main__.SceneLocation object at 0x7f02945ace48>
# <__main__.SceneLocation object at 0x7f02945ace80>
# <__main__.SceneLocation object at 0x7f02945aceb8>
# <__main__.SceneLocation object at 0x7f02945acef0>
# <__main__.SceneLocation object at 0x7f02945acf28>
# <__main__.SceneLocation object at 0x7f02945acf60>
# <__main__.SceneLocation object at 0x7f02945acf98>
# <__main__.SceneLocation object at 0x7f02945acfd0>
# <__main__.SceneLocation object at 0x7f02945ab048>
# <__main__.SceneLocation object at 0x7f02945ab080>
# <__main__.SceneLocation object at 0x7f02945ab0b8>
# <__main__.SceneLocation object at 0x7f02945ab0f0>
# <__main__.SceneLocation object at 0x7f02945ab128>
# <__main__.SceneLocation object at 0x7f02945ab160>
# <__main__.SceneLocation object at 0x7f02945ab198>
# ...
# <__main__.SceneLocation object at 0x7f0293bd5198>
# <__main__.SceneLocation object at 0x7f0293bd51d0>
# <__main__.SceneLocation object at 0x7f0293bd5208>
# <__main__.SceneLocation object at 0x7f0293bd5240>
# <__main__.SceneLocation object at 0x7f0293bd5278>
# <__main__.SceneLocation object at 0x7f0293bd52b0>
# <__main__.SceneLocation object at 0x7f0293bd52e8>
# <__main__.SceneLocation object at 0x7f0293bd5320>
# <__main__.SceneLocation object at 0x7f0293bd5358>
# <__main__.SceneLocation object at 0x7f0293bd5390>
# <__main__.SceneLocation object at 0x7f0293bd53c8>
# <__main__.SceneLocation object at 0x7f0293bd5400>
# <__main__.SceneLocation object at 0x7f0293bd5438>
# <__main__.SceneLocation object at 0x7f0293bd5470>
# <__main__.SceneLocation object at 0x7f0293bd54a8>
# <__main__.SceneLocation object at 0x7f0293bd54e0>
# <__main__.SceneLocation object at 0x7f0293bd5518>
# <__main__.SceneLocation object at 0x7f0293bd5550>
# <__main__.SceneLocation object at 0x7f0293bd5588>
# <__main__.SceneLocation object at 0x7f0293bd55c0>
# <__main__.SceneLocation object at 0x7f0293bd55f8>
# <__main__.SceneLocation object at 0x7f0293bd5630>
# <__main__.SceneLocation object at 0x7f0293bd5668>
# <__main__.SceneLocation object at 0x7f0293bd56a0>
# <__main__.SceneLocation object at 0x7f0293bd56d8>
# <__main__.SceneLocation object at 0x7f0293bd5710>
# <__main__.SceneLocation object at 0x7f0293bd5748>
# <__main__.SceneLocation object at 0x7f0293bd5780>
# <__main__.SceneLocation object at 0x7f0293bd57b8>
# <__main__.SceneLocation object at 0x7f0293bd57f0>
# <__main__.SceneLocation object at 0x7f0293bd5828>
# <__main__.SceneLocation object at 0x7f0293bd5860>
# <__main__.SceneLocation object at 0x7f0293bd5898>
# <__main__.SceneLocation object at 0x7f0293bd58d0>
# <__main__.SceneLocation object at 0x7f0293bd5908>
# <__main__.SceneLocation object at 0x7f0293bd5940>
# <__main__.SceneLocation object at 0x7f0293bd5978>
# <__main__.SceneLocation object at 0x7f0293bd59b0>
# <__main__.SceneLocation object at 0x7f0293bd59e8>
# <__main__.SceneLocation object at 0x7f0293bd5a20>
# <__main__.SceneLocation object at 0x7f0293bd5a58>
# <__main__.SceneLocation object at 0x7f0293bd5a90>
# <__main__.SceneLocation object at 0x7f0293bd5ac8>
# <__main__.SceneLocation object at 0x7f0293bd5b00>
# <__main__.SceneLocation object at 0x7f0293bd5b38>
# <__main__.SceneLocation object at 0x7f0293bd5b70>
# <__main__.SceneLocation object at 0x7f0293bd5ba8>
# <__main__.SceneLocation object at 0x7f0293bd5be0>
# <__main__.SceneLocation object at 0x7f0293bd5c18>
# <__main__.SceneLocation object at 0x7f0293bd5c50>
# <__main__.SceneLocation object at 0x7f0293bd5c88>
# <__main__.SceneLocation object at 0x7f0293bd5cc0>
# <__main__.SceneLocation object at 0x7f0293bd5cf8>
# <__main__.SceneLocation object at 0x7f0293bd5d30>
# <__main__.SceneLocation object at 0x7f0293bd5d68>
# <__main__.SceneLocation object at 0x7f0293bd5da0>
# <__main__.SceneLocation object at 0x7f0293bd5dd8>
# <__main__.SceneLocation object at 0x7f0293bd5e10>
# <__main__.SceneLocation object at 0x7f0293bd5e48>
# <__main__.SceneLocation object at 0x7f0293bd5e80>
# <__main__.SceneLocation object at 0x7f0293bd5eb8>
# <__main__.SceneLocation object at 0x7f0293bd5ef0>
# <__main__.SceneLocation object at 0x7f0293bd5f28>
# <__main__.SceneLocation object at 0x7f0293bd5f60>
# <__main__.SceneLocation object at 0x7f0293bd5f98>
# <__main__.SceneLocation object at 0x7f0293bd5fd0>
# <__main__.SceneLocation object at 0x7f0293bd3048>
# <__main__.SceneLocation object at 0x7f0293bd3080>
# <__main__.SceneLocation object at 0x7f0293bd30b8>
# <__main__.SceneLocation object at 0x7f0293bd30f0>
# <__main__.SceneLocation object at 0x7f0293bd3128>
# <__main__.SceneLocation object at 0x7f0293bd3160>
# <__main__.SceneLocation object at 0x7f0293bd3198>
# <__main__.SceneLocation object at 0x7f0293bd31d0>
# <__main__.SceneLocation object at 0x7f0293bd3208>
# <__main__.SceneLocation object at 0x7f0293bd3240>
# <__main__.SceneLocation object at 0x7f0293bd3278>
# <__main__.SceneLocation object at 0x7f0293bd32b0>
# <__main__.SceneLocation object at 0x7f0293bd32e8>
# <__main__.SceneLocation object at 0x7f0293bd3320>
# <__main__.SceneLocation object at 0x7f0293bd3358>
# <__main__.SceneLocation object at 0x7f0293bd3390>
# <__main__.SceneLocation object at 0x7f0293bd33c8>
# <__main__.SceneLocation object at 0x7f0293bd3400>
# <__main__.SceneLocation object at 0x7f0293bd3438>
# <__main__.SceneLocation object at 0x7f0293bd3470>
# <__main__.SceneLocation object at 0x7f0293bd34a8>
# <__main__.SceneLocation object at 0x7f0293bd34e0>
# <__main__.SceneLocation object at 0x7f0293bd3518>
# <__main__.SceneLocation object at 0x7f0293bd3550>
# <__main__.SceneLocation object at 0x7f0293bd3588>
# <__main__.SceneLocation object at 0x7f0293bd35c0>
# <__main__.SceneLocation object at 0x7f0293bd35f8>
# <__main__.SceneLocation object at 0x7f0293bd3630>
# <__main__.SceneLocation object at 0x7f0293bd3668>
# <__main__.SceneLocation object at 0x7f0293bd36a0>
# <__main__.SceneLocation object at 0x7f0293bd36d8>
# <__main__.SceneLocation object at 0x7f0293bd3710>
# <__main__.SceneLocation object at 0x7f0293bd3748>
# <__main__.SceneLocation object at 0x7f0293bd3780>
# <__main__.SceneLocation object at 0x7f0293bd37b8>
# <__main__.SceneLocation object at 0x7f0293bd37f0>
# <__main__.SceneLocation object at 0x7f0293bd3828>
# <__main__.SceneLocation object at 0x7f0293bd3860>
# <__main__.SceneLocation object at 0x7f0293bd3898>
# <__main__.SceneLocation object at 0x7f0293bd38d0>
# <__main__.SceneLocation object at 0x7f0293bd3908>
# <__main__.SceneLocation object at 0x7f0293bd3940>
# <__main__.SceneLocation object at 0x7f0293bd3978>
# <__main__.SceneLocation object at 0x7f0293bd39b0>
# <__main__.SceneLocation object at 0x7f0293bd39e8>
# <__main__.SceneLocation object at 0x7f0293bd3a20>
# <__main__.SceneLocation object at 0x7f0293bd3a58>
# <__main__.SceneLocation object at 0x7f0293bd3a90>
# <__main__.SceneLocation object at 0x7f0293bd3ac8>
# <__main__.SceneLocation object at 0x7f0293bd3b00>
# <__main__.SceneLocation object at 0x7f0293bd3b38>
# <__main__.SceneLocation object at 0x7f0293bd3b70>
# <__main__.SceneLocation object at 0x7f0293bd3ba8>
# <__main__.SceneLocation object at 0x7f0293bd3be0>
# <__main__.SceneLocation object at 0x7f0293bd3c18>
# <__main__.SceneLocation object at 0x7f0293bd3c50>
# <__main__.SceneLocation object at 0x7f0293bd3c88>
# <__main__.SceneLocation object at 0x7f0293bd3cc0>
# <__main__.SceneLocation object at 0x7f0293bd3cf8>
# <__main__.SceneLocation object at 0x7f0293bd3d30>
# <__main__.SceneLocation object at 0x7f0293bd3d68>
# <__main__.SceneLocation object at 0x7f0293bd3da0>
# <__main__.SceneLocation object at 0x7f0293bd3dd8>
# <__main__.SceneLocation object at 0x7f0293bd3e10>
# <__main__.SceneLocation object at 0x7f0293bd3e48>
# <__main__.SceneLocation object at 0x7f0293bd3e80>
# <__main__.SceneLocation object at 0x7f0293bd3eb8>
# <__main__.SceneLocation object at 0x7f0293bd3ef0>
# <__main__.SceneLocation object at 0x7f0293bd3f28>
# <__main__.SceneLocation object at 0x7f0293bd3f60>
# <__main__.SceneLocation object at 0x7f0293bd3f98>
# <__main__.SceneLocation object at 0x7f0293bd3fd0>
# <__main__.SceneLocation object at 0x7f0293bd1048>
# <__main__.SceneLocation object at 0x7f0293bd1080>
# <__main__.SceneLocation object at 0x7f0293bd10b8>
# <__main__.SceneLocation object at 0x7f0293bd10f0>
# <__main__.SceneLocation object at 0x7f0293bd1128>
# <__main__.SceneLocation object at 0x7f0293bd1160>
# <__main__.SceneLocation object at 0x7f0293bd1198>
# <__main__.SceneLocation object at 0x7f0293bd11d0>
# <__main__.SceneLocation object at 0x7f0293bd1208>
# <__main__.SceneLocation object at 0x7f0293bd1240>
# <__main__.SceneLocation object at 0x7f0293bd1278>
# <__main__.SceneLocation object at 0x7f0293bd12b0>
# <__main__.SceneLocation object at 0x7f0293bd12e8>
# <__main__.SceneLocation object at 0x7f0293bd1320>
# <__main__.SceneLocation object at 0x7f0293bd1358>
# <__main__.SceneLocation object at 0x7f0293bd1390>
# <__main__.SceneLocation object at 0x7f0293bd13c8>
# <__main__.SceneLocation object at 0x7f0293bd1400>
# <__main__.SceneLocation object at 0x7f0293bd1438>
# <__main__.SceneLocation object at 0x7f0293bd1470>
# <__main__.SceneLocation object at 0x7f0293bd14a8>
# <__main__.SceneLocation object at 0x7f0293bd14e0>
# <__main__.SceneLocation object at 0x7f0293bd1518>
# <__main__.SceneLocation object at 0x7f0293bd1550>
# <__main__.SceneLocation object at 0x7f0293bd1588>
# <__main__.SceneLocation object at 0x7f0293bd15c0>
# <__main__.SceneLocation object at 0x7f0293bd15f8>
# <__main__.SceneLocation object at 0x7f0293bd1630>
# <__main__.SceneLocation object at 0x7f0293bd1668>
# <__main__.SceneLocation object at 0x7f0293bd16a0>
# <__main__.SceneLocation object at 0x7f0293bd16d8>
# <__main__.SceneLocation object at 0x7f0293bd1710>
# <__main__.SceneLocation object at 0x7f0293bd1748>
# <__main__.SceneLocation object at 0x7f0293bd1780>
# <__main__.SceneLocation object at 0x7f0293bd17b8>
# <__main__.SceneLocation object at 0x7f0293bd17f0>
# <__main__.SceneLocation object at 0x7f0293bd1828>
# <__main__.SceneLocation object at 0x7f0293bd1860>
# <__main__.SceneLocation object at 0x7f0293bd1898>
# <__main__.SceneLocation object at 0x7f0293bd18d0>
# <__main__.SceneLocation object at 0x7f0293bd1908>
# <__main__.SceneLocation object at 0x7f0293bd1940>
# <__main__.SceneLocation object at 0x7f0293bd1978>
# <__main__.SceneLocation object at 0x7f0293bd19b0>
# <__main__.SceneLocation object at 0x7f0293bd19e8>
# <__main__.SceneLocation object at 0x7f0293bd1a20>
# <__main__.SceneLocation object at 0x7f0293bd1a58>
# <__main__.SceneLocation object at 0x7f0293bd1a90>
# <__main__.SceneLocation object at 0x7f0293bd1ac8>
# <__main__.SceneLocation object at 0x7f0293bd1b00>
# <__main__.SceneLocation object at 0x7f0293bd1b38>
# <__main__.SceneLocation object at 0x7f0293bd1b70>
# <__main__.SceneLocation object at 0x7f0293bd1ba8>
# <__main__.SceneLocation object at 0x7f0293bd1be0>
# <__main__.SceneLocation object at 0x7f0293bd1c18>
# <__main__.SceneLocation object at 0x7f0293bd1c50>
# <__main__.SceneLocation object at 0x7f0293bd1c88>
# <__main__.SceneLocation object at 0x7f0293bd1cc0>
# <__main__.SceneLocation object at 0x7f0293bd1cf8>
# <__main__.SceneLocation object at 0x7f0293bd1d30>
# <__main__.SceneLocation object at 0x7f0293bd1d68>
# <__main__.SceneLocation object at 0x7f0293bd1da0>
# <__main__.SceneLocation object at 0x7f0293bd1dd8>
# <__main__.SceneLocation object at 0x7f0293bd1e10>
# <__main__.SceneLocation object at 0x7f0293bd1e48>
# <__main__.SceneLocation object at 0x7f0293bd1e80>
# <__main__.SceneLocation object at 0x7f0293bd1eb8>
# <__main__.SceneLocation object at 0x7f0293bd1ef0>
# <__main__.SceneLocation object at 0x7f0293bd1f28>
# <__main__.SceneLocation object at 0x7f0293bd1f60>
# <__main__.SceneLocation object at 0x7f0293bd1f98>
# <__main__.SceneLocation object at 0x7f0293bd1fd0>
# <__main__.SceneLocation object at 0x7f0293bce048>
# <__main__.SceneLocation object at 0x7f0293bce080>
# <__main__.SceneLocation object at 0x7f0293bce0b8>
# <__main__.SceneLocation object at 0x7f0293bce0f0>
# <__main__.SceneLocation object at 0x7f0293bce128>
# <__main__.SceneLocation object at 0x7f0293bce160>
# <__main__.SceneLocation object at 0x7f0293bce198>
# <__main__.SceneLocation object at 0x7f0293bce1d0>
# <__main__.SceneLocation object at 0x7f0293bce208>
# <__main__.SceneLocation object at 0x7f0293bce240>
# <__main__.SceneLocation object at 0x7f0293bce278>
# <__main__.SceneLocation object at 0x7f0293bce2b0>
# <__main__.SceneLocation object at 0x7f0293bce2e8>
# <__main__.SceneLocation object at 0x7f0293bce320>
# <__main__.SceneLocation object at 0x7f0293bce358>
# <__main__.SceneLocation object at 0x7f0293bce390>
# <__main__.SceneLocation object at 0x7f0293bce3c8>
# <__main__.SceneLocation object at 0x7f0293bce400>
# <__main__.SceneLocation object at 0x7f0293bce438>
# <__main__.SceneLocation object at 0x7f0293bce470>
# <__main__.SceneLocation object at 0x7f0293bce4a8>
# <__main__.SceneLocation object at 0x7f0293bce4e0>
# <__main__.SceneLocation object at 0x7f0293bce518>
# <__main__.SceneLocation object at 0x7f0293bce550>
# <__main__.SceneLocation object at 0x7f0293bce588>
# <__main__.SceneLocation object at 0x7f0293bce5c0>
# <__main__.SceneLocation object at 0x7f0293bce5f8>
# <__main__.SceneLocation object at 0x7f0293bce630>
# <__main__.SceneLocation object at 0x7f0293bce668>
# <__main__.SceneLocation object at 0x7f0293bce6a0>
# <__main__.SceneLocation object at 0x7f0293bce6d8>
# <__main__.SceneLocation object at 0x7f0293bce710>
# <__main__.SceneLocation object at 0x7f0293bce748>
# <__main__.SceneLocation object at 0x7f0293bce780>
# <__main__.SceneLocation object at 0x7f0293bce7b8>
# <__main__.SceneLocation object at 0x7f0293bce7f0>
# <__main__.SceneLocation object at 0x7f0293bce828>
# <__main__.SceneLocation object at 0x7f0293bce860>
# <__main__.SceneLocation object at 0x7f0293bce898>
# <__main__.SceneLocation object at 0x7f0293bce8d0>
# <__main__.SceneLocation object at 0x7f0293bce908>
# <__main__.SceneLocation object at 0x7f0293bce940>
# <__main__.SceneLocation object at 0x7f0293bce978>
# <__main__.SceneLocation object at 0x7f0293bce9b0>
# <__main__.SceneLocation object at 0x7f0293bce9e8>
# <__main__.SceneLocation object at 0x7f0293bcea20>
# <__main__.SceneLocation object at 0x7f0293bcea58>
# <__main__.SceneLocation object at 0x7f0293bcea90>
# <__main__.SceneLocation object at 0x7f0293bceac8>
# <__main__.SceneLocation object at 0x7f0293bceb00>
# <__main__.SceneLocation object at 0x7f0293bceb38>
# <__main__.SceneLocation object at 0x7f0293bceb70>
# <__main__.SceneLocation object at 0x7f0293bceba8>
# <__main__.SceneLocation object at 0x7f0293bcebe0>
# <__main__.SceneLocation object at 0x7f0293bcec18>
# <__main__.SceneLocation object at 0x7f0293bcec50>
# <__main__.SceneLocation object at 0x7f0293bcec88>
# <__main__.SceneLocation object at 0x7f0293bcecc0>
# <__main__.SceneLocation object at 0x7f0293bcecf8>
# <__main__.SceneLocation object at 0x7f0293bced30>
# <__main__.SceneLocation object at 0x7f0293bced68>
# <__main__.SceneLocation object at 0x7f0293bceda0>
# <__main__.SceneLocation object at 0x7f0293bcedd8>
# <__main__.SceneLocation object at 0x7f0293bcee10>
# <__main__.SceneLocation object at 0x7f0293bcee48>
# <__main__.SceneLocation object at 0x7f0293bcee80>
# <__main__.SceneLocation object at 0x7f0293bceeb8>
# <__main__.SceneLocation object at 0x7f0293bceef0>
# <__main__.SceneLocation object at 0x7f0293bcef28>
# <__main__.SceneLocation object at 0x7f0293bcef60>
# <__main__.SceneLocation object at 0x7f0293bcef98>
# <__main__.SceneLocation object at 0x7f0293bcefd0>
# <__main__.SceneLocation object at 0x7f0293bcc048>
# <__main__.SceneLocation object at 0x7f0293bcc080>
# <__main__.SceneLocation object at 0x7f0293bcc0b8>
# <__main__.SceneLocation object at 0x7f0293bcc0f0>
# <__main__.SceneLocation object at 0x7f0293bcc128>
# <__main__.SceneLocation object at 0x7f0293bcc160>
# <__main__.SceneLocation object at 0x7f0293bcc198>
# <__main__.SceneLocation object at 0x7f0293bcc1d0>
# <__main__.SceneLocation object at 0x7f0293bcc208>
# <__main__.SceneLocation object at 0x7f0293bcc240>
# <__main__.SceneLocation object at 0x7f0293bcc278>
# <__main__.SceneLocation object at 0x7f0293bcc2b0>
# <__main__.SceneLocation object at 0x7f0293bcc2e8>
# <__main__.SceneLocation object at 0x7f0293bcc320>
# <__main__.SceneLocation object at 0x7f0293bcc358>
# <__main__.SceneLocation object at 0x7f0293bcc390>
# <__main__.SceneLocation object at 0x7f0293bcc3c8>
# <__main__.SceneLocation object at 0x7f0293bcc400>
# <__main__.SceneLocation object at 0x7f0293bcc438>
# <__main__.SceneLocation object at 0x7f0293bcc470>
# <__main__.SceneLocation object at 0x7f0293bcc4a8>
# <__main__.SceneLocation object at 0x7f0293bcc4e0>
# <__main__.SceneLocation object at 0x7f0293bcc518>
# <__main__.SceneLocation object at 0x7f0293bcc550>
# <__main__.SceneLocation object at 0x7f0293bcc588>
# <__main__.SceneLocation object at 0x7f0293bcc5c0>
# <__main__.SceneLocation object at 0x7f0293bcc5f8>
# <__main__.SceneLocation object at 0x7f0293bcc630>
# <__main__.SceneLocation object at 0x7f0293bcc668>
# <__main__.SceneLocation object at 0x7f0293bcc6a0>
# <__main__.SceneLocation object at 0x7f0293bcc6d8>
# <__main__.SceneLocation object at 0x7f0293bcc710>
# <__main__.SceneLocation object at 0x7f0293bcc748>
# <__main__.SceneLocation object at 0x7f0293bcc780>
# <__main__.SceneLocation object at 0x7f0293bcc7b8>
# <__main__.SceneLocation object at 0x7f0293bcc7f0>
# <__main__.SceneLocation object at 0x7f0293bcc828>
# <__main__.SceneLocation object at 0x7f0293bcc860>

# %%
df3 = pd.DataFrame.from_records([s.to_dict() for s in rows])
df3.to_csv('locations.csv')
df3.head()
# Out:
#    episode           location  season  weight
# 0        1           The Wall       1      65
# 1        1  North of the Wall       1      99
# 2        1  North of the Wall       1       7
# 3        1  North of the Wall       1       7
# 4        1  North of the Wall       1       6

# %%
dd = [dict() for i in range(7)]
for episode in data['episodes']:
    season = episode['seasonNum']
    for scene in episode['scenes']:
        scene_length = get_seconds(scene['sceneEnd'])- get_seconds(scene['sceneStart'])
        characters = []
        for character in scene['characters']:
            characters.append(character['name'])
        characters = sorted(characters)
        for i in range(len(characters)):
            if characters[i] in dd[season-1]:
                dd[season-1][characters[i]] = dd[season-1][characters[i]] + scene_length
            else:
                dd[season-1][characters[i]] = scene_length

# %%
for i in range(7):
    print(max(dd[i], key=dd[i].get))
# Out:
# Eddard Stark
# Tyrion Lannister
# Tyrion Lannister
# Tyrion Lannister
# Jon Snow
# Jon Snow
# Jon Snow
