# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline

# %%
dane = pd.read_csv("data/TWD_data_words.csv")
dane = dane.fillna(0)
indx = dane.shape[0] - 2

# %%
d = {}
for a, x in zip(dane.iloc[indx].index.values,dane.iloc[indx].values):
    a = a.replace("itc","**t")\
        .replace("agg","**g")\
        .replace("itt","**t")\
        .replace("ick","**k")\
        .replace("wat","w*t")\
        .replace("igg","**g")\
        .replace("i","*")\
        .replace("uc","**")\
        .replace("or","*r")\
        .replace("un","*n")\
        .upper()
    d[a] = x

# %%
wordcloud = WordCloud(min_font_size=12, width=1536, height=512, mode="RGBA", background_color=None,color_func=lambda *args, **kwargs: (255,172,50))
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize = (30,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig('wordCloud.svg', format="svg")

# %%
# ?WordCloud

# %%
#5b9aff

# %%
#ffac32
#8000c1
